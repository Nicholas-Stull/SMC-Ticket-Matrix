# %%
def update_category_dropdown():
    # Load the categories from the CSV file
    maincat = 'src/csv/categories.csv'
    with open(maincat, encoding='utf-8-sig') as f:
        reader = csv.reader(f)
        # next(reader)  # Skip header row
        categories = [row[0] for row in reader]

    # Update the search bar with the categories
    search_bar['values'] = categories


def update_listbox(event=None):
    # Get the search query from the search bar
    search_query = search_var.get()

    # Load all data from CSV files
    all_data = []
    for category in category_dropdown['values']:
        filename = f'src/csv/{category}.csv'
        strippedcat = filename.replace(" ", "").lower()
        with open(strippedcat, encoding='utf-8-sig') as f:
            reader = csv.reader(f)
            data = list(reader)
            all_data += [(category, row) for row in data]

    # Filter data by search query
    filtered_data = [
        row for row in all_data if search_query.lower() in row[1][0].lower()]

    # Update the Listbox with the filtered data
    var.set([row[1][0] for row in filtered_data])

    # Clear the labels
    catset2.config(text="")
    prim2.config(text="")
    sec2.config(text="")
    tri2.config(text="")

    # Show the labels only if a search result is selected
    if listbox1.curselection():
        selected_row = filtered_data[listbox1.curselection()[0]]
        catset2.config(text=selected_row[0])
        prim2.config(text=selected_row[1][1])
        sec2.config(text=selected_row[1][2])
        tri2.config(text=selected_row[1][3])


# Set up the GUI
root = Tk()
root.geometry('380x320')

# Create a canvas to hold the image and header
canvas = tk.Canvas(root, width=200, height=50)
canvas.grid(row=0, column=1, sticky='ne')

# Load the image and add it to the canvas
# sets the image paths to easily change them later
smc_logo = './src/images/smc-logo.png'
smc_seal = './src/images/smc-seal.png'

# %%
import tkinter as tk
from tkinter import ttk
from tkinter import *
import csv


def update_category_dropdown():
    # Load the categories from the CSV file
    maincat = 'src/csv/categories.csv'
    with open(maincat, encoding='utf-8-sig') as f:
        reader = csv.reader(f)
        # next(reader)  # Skip header row
        categories = [row[0] for row in reader]

    # Update the dropdown list with the categories
    category_dropdown['values'] = categories
    category_dropdown.current(0)  # Set default selection


def update_listbox(*args):
    # Load the data from the selected category file
    cat_picked = category_var.get()
    filename = f'src/csv/{cat_picked}.csv'
    strippedcat = filename.replace(" ", "").lower()
    with open(strippedcat, encoding='utf-8-sig') as f:
        reader = csv.reader(f)
        data = list(reader)

    # Clear the labels
    catset2.config(text="")
    prim2.config(text="")
    sec2.config(text="")
    tri2.config(text="")

    # Update the Listbox with the data
    var.set([row[0] for row in data])

    # Get the selected row and update the labels with its data
    try:
        selected_row = data[listbox1.curselection()[0]]
        catset2.config(text=selected_row[0])
        prim2.config(text=selected_row[1])
        sec2.config(text=selected_row[2])
        tri2.config(text=selected_row[3])
    except IndexError:
        pass


def filter_categories(*args):
    search_term = search_var.get().lower()
    filtered_categories = [
        cat for cat in all_categories if search_term in cat.lower()]
    category_dropdown['values'] = filtered_categories
    if filtered_categories:
        category_dropdown.current(0)
    else:
        category_dropdown.set('')


# Set up the GUI
root = Tk()
root.geometry('380x320')
# Create a canvas to hold the image and header
canvas = tk.Canvas(root, width=200, height=50)
canvas.grid(row=0, column=1, sticky='ne')

# Load the image and add it to the canvas
# sets the image paths to easily change them later
smc_logo = './src/images/smc-logo.png'
smc_seal = './src/images/smc-seal.png'


img = PhotoImage(file=smc_seal)
img = img.subsample(4)  # resize the image to 1/4 of its original size
canvas.create_image(0, 0, anchor='nw', image=img)
canvas.grid(row=0, column=0, sticky='nw')

# Add the header text to the canvas
header_text = "SMC Ticket Matrix"
canvas.create_text(110, 25, text=header_text, fill='green')

# Create the search bar
search_label = ttk.Label(text="Search Category:")
search_label.grid(row=1, column=0)
search_var = tk.StringVar()
search_var.trace_add('write', filter_categories)
search_entry = ttk.Entry(textvariable=search_var, width=25)
search_entry.grid(row=1, column=1, sticky='new')

# Load all categories and set up the dropdown
all_categories = []
maincat = []

def search_categories():
    search_query = search_bar.get()
    matches = []
    with open('src/csv/categories.csv', encoding='utf-8-sig') as f:
        reader = csv.reader(f)
        next(reader)  # Skip header row
        for row in reader:
            if search_query.lower() in row[0].lower():
                matches.append(row[0])

    category_dropdown['values'] = matches
    category_dropdown.current(0)  # Set default selection


# Add the search bar
search_bar = Entry(root, width=30)
search_bar.grid(row=2, column=1, sticky='w')
search_button = Button(root, text='Search', command=search_categories)
search_button.grid(row=2, column=1, sticky='e')


# Update the labels with the selected item from the dropdown
def update_labels(*args):
    cat_picked = category_var.get()
    filename = f'src/csv/{cat_picked}.csv'
    strippedcat = filename.replace(" ", "").lower()
    with open(strippedcat, encoding='utf-8-sig') as f:
        reader = csv.reader(f)
        data = list(reader)

    # Clear the labels
    catset2.config(text="")
    prim2.config(text="")
    sec2.config(text="")
    tri2.config(text="")

    # Update the Listbox with the data
    var.set([row[0] for row in data])

    # Get the selected row and update the labels with its data
    try:
        selected_row = data[listbox1.curselection()[0]]
        catset2.config(text=selected_row[0])
        prim2.config(text=selected_row[1])
        sec2.config(text=selected_row[2])
        tri2.config(text=selected_row[3])
    except IndexError:
        pass


# Update the labels when a new item is selected from the dropdown
category_var.trace_add('write', update_labels)


root.title("SMC Ticket Matrix")
root.mainloop()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 92
#      90 # Load all categories and set up the dropdown
#      91 all_categories = []
# ---> 92 maincat
#
# NameError: name 'maincat' is not defined

# %%
import tkinter as tk
from tkinter import ttk
import csv

# Define function to search for items in CSV file


def search_items():
    search_term = search_var.get()
    results_box.delete(0, tk.END)  # Clear listbox
    for item in items:
        if search_term.lower() in item[0].lower():
            results_box.insert(tk.END, item[0])
    update_labels()  # Update labels with new selection

# Define function to update labels when a new item is selected in the listbox


def update_labels():
    selection = results_box.get(tk.ACTIVE)
    for item in items:
        if item[0] == selection:
            primary_var.set(item[1])
            secondary_var.set(item[2])
            third_var.set(item[3])

# Define function to switch between dark and light modes


def switch_theme():
    if root.theme_use() == "dark":
        root.theme_use("light")
    else:
        root.theme_use("dark")


# Load items from CSV file
filename = 'src/csv/TheMatrix.csv'
with open(filename, newline='') as csvfile:
    items_reader = csv.reader(csvfile)
    items = list(items_reader)

# Create GUI
root = tk.Tk()
root.title("Search Bar Example")
root.geometry("400x300")

# Create search bar
search_var = tk.StringVar()
search_bar = ttk.Entry(root, textvariable=search_var, width=30)
search_bar.grid(row=0, column=0, padx=10, pady=10)
search_button = ttk.Button(root, text="Search", command=search_items)
search_button.grid(row=0, column=1)

# Create listbox to display search results
results_box = tk.Listbox(root, width=40)
results_box.grid(row=1, column=0, padx=10, pady=10, columnspan=2)
results_box.bind('<<ListboxSelect>>', lambda event: update_labels())

# Create labels to display information about selected item
primary_var = tk.StringVar()
primary_label = ttk.Label(root, textvariable=primary_var)
primary_label.grid(row=2, column=0, padx=10, pady=5)
secondary_var = tk.StringVar()
secondary_label = ttk.Label(root, textvariable=secondary_var)
secondary_label.grid(row=2, column=1, padx=10, pady=5)
third_var = tk.StringVar()
third_label = ttk.Label(root, textvariable=third_var)
third_label.grid(row=3, column=0, padx=10, pady=5)

# Create button to switch between dark and light modes
theme_button = ttk.Button(root, text="Switch Theme", command=switch_theme)
theme_button.grid(row=3, column=1, padx=10, pady=5)

# Set dark theme by default
root.theme_use("dark")

# Start GUI
root.mainloop()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 76
#      73 theme_button.grid(row=3, column=1, padx=10, pady=5)
#      75 # Set dark theme by default
# ---> 76 root.theme_use("dark")
#      78 # Start GUI
#      79 root.mainloop()
#
# File c:\Users\nstull\AppData\Local\Programs\Python\Python311\Lib\tkinter\__init__.py:2410, in Tk.__getattr__(self, attr)
#    2408 def __getattr__(self, attr):
#    2409     "Delegate attribute access to the interpreter object"
# -> 2410     return getattr(self.tk, attr)
#
# AttributeError: '_tkinter.tkapp' object has no attribute 'theme_use'

# %%
import tkinter as tk
from tkinter import ttk
import csv

# Define function to search for items in CSV file


def search_items():
    search_term = search_var.get()
    results_box.delete(0, tk.END)  # Clear listbox
    for item in items:
        if search_term.lower() in item[0].lower():
            results_box.insert(tk.END, item[0])
    update_labels()  # Update labels with new selection

# Define function to update labels when a new item is selected in the listbox


def update_labels():
    selection = results_box.get(tk.ACTIVE)
    for item in items:
        if item[0] == selection:
            primary_var.set(item[1])
            secondary_var.set(item[2])
            third_var.set(item[3])

# Define function to switch between dark and light modes


def switch_theme():
    if style.theme_use() == "dark":
        style.theme_use("clam")
    else:
        style.theme_use("dark")


# Load items from CSV file
filename = 'src/csv/TheMatrix.csv'
with open(filename, newline='') as csvfile:
    items_reader = csv.reader(csvfile)
    items = list(items_reader)

# Create GUI
root = tk.Tk()
root.title("Search Bar Example")
root.geometry("400x300")

# Create search bar
search_var = tk.StringVar()
search_bar = ttk.Entry(root, textvariable=search_var, width=30)
search_bar.grid(row=0, column=0, padx=10, pady=10)
search_button = ttk.Button(root, text="Search", command=search_items)
search_button.grid(row=0, column=1)

# Create listbox to display search results
results_box = tk.Listbox(root, width=40)
results_box.grid(row=1, column=0, padx=10, pady=10, columnspan=2)
results_box.bind('<<ListboxSelect>>', lambda event: update_labels())

# Create labels to display information about selected item
primary_var = tk.StringVar()
primary_label = ttk.Label(root, textvariable=primary_var)
primary_label.grid(row=2, column=0, padx=10, pady=5)
secondary_var = tk.StringVar()
secondary_label = ttk.Label(root, textvariable=secondary_var)
secondary_label.grid(row=2, column=1, padx=10, pady=5)
third_var = tk.StringVar()
third_label = ttk.Label(root, textvariable=third_var)
third_label.grid(row=3, column=0, padx=10, pady=5)

# Create button to switch between dark and light modes
#style = ttk.Style()
#theme_button = ttk.Button(root, text="Switch Theme", command=switch_theme)
#theme_button.grid(row=3, column=1, padx=10, pady=5)

# Set dark theme by default
#style.theme_use("dark")

# Start GUI
root.mainloop()

# %%
import tkinter as tk
from tkinter import ttk
import csv

# Define function to search for items in CSV file


def search_items(event=None):
    search_term = search_var.get()
    results_box.delete(0, tk.END)  # Clear listbox
    for item in items:
        if search_term.lower() in item[0].lower():
            results_box.insert(tk.END, item[0])
    update_labels()  # Update labels with new selection

# Define function to update labels when a new item is selected in the listbox


def update_labels():
    selection = results_box.get(tk.ACTIVE)
    for item in items:
        if item[0] == selection:
            primary_var.set(item[1])
            secondary_var.set(item[2])
            third_var.set(item[3])

# Define function to switch between dark and light modes


def switch_theme():
    if style.theme_use() == "dark":
        style.theme_use("clam")
    else:
        style.theme_use("dark")


# Load items from CSV file
with open('src/csv/TheMatrix.csv', newline='') as csvfile:
    items_reader = csv.reader(csvfile)
    items = list(items_reader)

# Create GUI
root = tk.Tk()
root.title("Search Bar Example")
root.geometry("400x300")

# Create search bar
search_var = tk.StringVar()
search_bar = ttk.Entry(root, textvariable=search_var, width=30)
search_bar.grid(row=0, column=0, padx=10, pady=10)
# Bind search function to key release event
search_bar.bind('<KeyRelease>', search_items)
search_button = ttk.Button(root, text="Search", command=search_items)
search_button.grid(row=0, column=1)

# Create listbox to display search results
results_box = tk.Listbox(root, width=40)
results_box.grid(row=1, column=0, padx=10, pady=10, columnspan=2)
results_box.bind('<<ListboxSelect>>', lambda event: update_labels())

# Create labels to display information about selected item
primary_var = tk.StringVar()
primary_label = ttk.Label(root, textvariable=primary_var)
primary_label.grid(row=2, column=0, padx=10, pady=5)
secondary_var = tk.StringVar()
secondary_label = ttk.Label(root, textvariable=secondary_var)
secondary_label.grid(row=2, column=1, padx=10, pady=5)
third_var = tk.StringVar()
third_label = ttk.Label(root, textvariable=third_var)
third_label.grid(row=3, column=0, padx=10, pady=5)

# Create button to switch between dark and light modes
style = ttk.Style()
theme_button = ttk.Button(root, text="Switch Theme", command=switch_theme)
theme_button.grid(row=3, column=1, padx=10, pady=5)

# Set dark theme by default
style.theme_use("dark")

# Start GUI
root.mainloop()
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# Cell In[10], line 78
#      75 theme_button.grid(row=3, column=1, padx=10, pady=5)
#      77 # Set dark theme by default
# ---> 78 style.theme_use("dark")
#      80 # Start GUI
#      81 root.mainloop()
#
# File c:\Users\nstull\AppData\Local\Programs\Python\Python311\Lib\tkinter\ttk.py:500, in Style.theme_use(self, themename)
#     495     return self.tk.eval("return $ttk::currentTheme")
#     497 # using "ttk::setTheme" instead of "ttk::style theme use" causes
#     498 # the variable currentTheme to be updated, also, ttk::setTheme calls
#     499 # "ttk::style theme use" in order to change theme.
# --> 500 self.tk.call("ttk::setTheme", themename)
#
# TclError: can't find package ttk::theme::dark

# %%
import tkinter as tk
from tkinter import ttk
import csv

# Define function to search for items in CSV file


def search_items(event=None):
    search_term = search_var.get()
    results_box.delete(0, tk.END)  # Clear listbox
    for item in items:
        if search_term.lower() in item[0].lower():
            results_box.insert(tk.END, item[0])
    update_labels()  # Update labels with new selection

# Define function to update labels when a new item is selected in the listbox


def update_labels():
    selection = results_box.get(tk.ACTIVE)
    for item in items:
        if item[0] == selection:
            primary_var.set(item[1])
            secondary_var.set(item[2])
            third_var.set(item[3])


# Load items from CSV file
with open('src/csv/TheMatrix.csv', newline='') as csvfile:
    items_reader = csv.reader(csvfile)
    items = list(items_reader)

# Create GUI
root = tk.Tk()
root.title("Search Bar Example")
root.geometry("400x300")

# Create search bar
search_var = tk.StringVar()
search_bar = ttk.Entry(root, textvariable=search_var, width=30)
search_bar.grid(row=0, column=0, padx=10, pady=10)
# Bind search function to key release event
search_bar.bind('<KeyRelease>', search_items)
search_button = ttk.Button(root, text="Search", command=search_items)
search_button.grid(row=0, column=1)

# Create listbox to display search results
results_box = tk.Listbox(root, width=40)
results_box.grid(row=1, column=0, padx=10, pady=10, columnspan=2)
results_box.bind('<<ListboxSelect>>', lambda event: update_labels())

# Create labels to display information about selected item
primary_var = tk.StringVar()
primary_label = ttk.Label(root, textvariable=primary_var)
primary_label.grid(row=2, column=0, padx=10, pady=5)
secondary_var = tk.StringVar()
secondary_label = ttk.Label(root, textvariable=secondary_var)
secondary_label.grid(row=2, column=1, padx=10, pady=5)
third_var = tk.StringVar()
third_label = ttk.Label(root, textvariable=third_var)
third_label.grid(row=3, column=0, padx=10, pady=5)
# Make the first labels
primlabel = tkk.label(root, text="Primary")
primlabel.grid(row=2, column=0, padx=10, pady=5)
seclabel = tkk.label(root, text="Secondary")
seclabel.grid(row=2, column=1, padx=10, pady=5)
thirdlabel = tkk.label(root, text="Third")
thirdlabel.grid(row=3, column=0, padx=10, pady=5)

# Start GUI
root.mainloop()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 52
#      50 results_box.bind('<<ListboxSelect>>', lambda event: update_labels())
#      51 # Make the first labels
# ---> 52 primlabel = tkk.label(root, text="Primary")
#      53 primlabel.grid(row=2, column=0, padx=10, pady=5)
#      54 seclabel = tkk.label(root, text="Secondary")
#
# NameError: name 'tkk' is not defined

# %%
import tkinter as tk
from tkinter import ttk
import csv

# Define function to search for items in CSV file


def search_items(event=None):
    search_term = search_var.get()
    results_box.delete(0, tk.END)  # Clear listbox
    for item in items:
        if search_term.lower() in item[0].lower():
            results_box.insert(tk.END, item[0])
    update_labels()  # Update labels with new selection

# Define function to update labels when a new item is selected in the listbox


def update_labels():
    selection = results_box.get(tk.ACTIVE)
    for item in items:
        if item[0] == selection:
            primary_var.set(item[1])
            secondary_var.set(item[2])
            third_var.set(item[3])


# Load items from CSV file
with open('src/csv/TheMatrix.csv', newline='') as csvfile:
    items_reader = csv.reader(csvfile)
    items = list(items_reader)

# Create GUI
root = tk.Tk()
root.title("Search Bar Example")
root.geometry("400x300")

# Create search bar
search_var = tk.StringVar()
search_bar = ttk.Entry(root, textvariable=search_var, width=30)
search_bar.grid(row=0, column=0, padx=10, pady=10)
# Bind search function to key release event
search_bar.bind('<KeyRelease>', search_items)
# Bind search function to Return key press event
search_bar.bind('<Return>', search_items)

# Create listbox to display search results
results_box = tk.Listbox(root, width=40)
results_box.grid(row=1, column=0, padx=10, pady=10, columnspan=2)
results_box.bind('<<ListboxSelect>>', lambda event: update_labels())

# Create labels to display information about selected item
primary_var = tk.StringVar()
primary_label = ttk.Label(root, textvariable=primary_var)
primary_label.grid(row=2, column=0, padx=10, pady=5)
secondary_var = tk.StringVar()
secondary_label = ttk.Label(root, textvariable=secondary_var)
secondary_label.grid(row=2, column=1, padx=10, pady=5)
third_var = tk.StringVar()
third_label = ttk.Label(root, textvariable=third_var)
third_label.grid(row=3, column=0, padx=10, pady=5)

# Start GUI
root.mainloop()

# %%
import tkinter as tk
from tkinter import ttk
import csv

# Define function to search for items in CSV file


def search_items(event=None):
    search_term = search_var.get()
    results_box.delete(0, tk.END)  # Clear listbox
    for item in items:
        if search_term.lower() in item[0].lower():
            results_box.insert(tk.END, item[0])
    update_labels()  # Update labels with new selection

# Define function to update labels when a new item is selected in the listbox


def update_labels(event=None):
    selection = results_box.get(tk.ACTIVE)
    selection_var.set(selection)
    for item in items:
        if item[0] == selection:
            primary_var.set(item[1])
            secondary_var.set(item[2])
            third_var.set(item[3])


# Load items from CSV file
with open('src/csv/TheMatrix.csv', newline='') as csvfile:
    items_reader = csv.reader(csvfile)
    items = list(items_reader)

# Create GUI
root = tk.Tk()
root.title("Ticket Matrix Search Bar")
root.geometry("300x320")

# Create search bar
search_var = tk.StringVar()
search_bar = ttk.Entry(root, textvariable=search_var, width=30)
search_bar.grid(row=0, column=0, padx=10, pady=10)
# Bind search function to key release event
search_bar.bind('<KeyRelease>', search_items)
# Bind search function to Return key press event
search_bar.bind('<Return>', search_items)

# Create label to display current selection
selection_var = tk.StringVar()
selection_label = ttk.Label(root, textvariable=selection_var)
selection_label.grid(row=1, column=0, padx=10, pady=5)

# Create listbox to display search results
results_box = tk.Listbox(root, width=40)
results_box.grid(row=2, column=0, padx=10, pady=10)
results_box.bind('<<ListboxSelect>>', update_labels)

# Create labels to display information about selected item
primary_var = tk.StringVar()
primary_label = ttk.Label(root, textvariable=primary_var)
primary_label.grid(row=3, column=0, padx=10, pady=5)
secondary_var = tk.StringVar()
secondary_label = ttk.Label(root, textvariable=secondary_var)
secondary_label.grid(row=4, column=0, padx=10, pady=5)
third_var = tk.StringVar()
third_label = ttk.Label(root, textvariable=third_var)
third_label.grid(row=5, column=0, padx=10, pady=5)

# Start GUI
root.mainloop()

# %%
import tkinter as tk
from tkinter import ttk
import csv

# Define function to search for items in CSV file


def search_items(event=None):
    search_term = search_var.get()
    for item in items:
        if search_term.lower() in item[0].lower():
            selection_var.set(item[0])
            primary_var.set(item[1])
            secondary_var.set(item[2])
            third_var.set(item[3])
            break  # Stop searching after first match
    else:
        selection_var.set("No matches found")
        primary_var.set("")
        secondary_var.set("")
        third_var.set("")


# Load items from CSV file
with open('src/csv/TheMatrix.csv', newline='') as csvfile:
    items_reader = csv.reader(csvfile)
    items = list(items_reader)

# Create GUI
root = tk.Tk()
root.title("Search Bar with Combobox")
root.geometry("400x300")

# Create search box
search_var = tk.StringVar()
search_box = ttk.Combobox(root, textvariable=search_var, values=[
                          item[0] for item in items])
search_box.grid(row=0, column=1, padx=10, pady=10)
# Bind search function to selection event
search_box.bind('<<ComboboxSelected>>', search_items)

# Create label to display "Selection"
selection_label_text = tk.StringVar(value="Selection")
selection_label = ttk.Label(root, textvariable=selection_label_text)
selection_label.grid(row=1, column=0, padx=10, pady=5, sticky=tk.W)

# Create label to display current selection
selection_var = tk.StringVar()
selection_label = ttk.Label(root, textvariable=selection_var)
selection_label.grid(row=1, column=1, padx=10, pady=5, sticky=tk.W)

# Create label to display "Primary"
primary_label_text = tk.StringVar(value="Primary")
primary_label = ttk.Label(root, textvariable=primary_label_text)
primary_label.grid(row=2, column=0, padx=10, pady=5, sticky=tk.W)

# Create labels to display information about selected item
primary_var = tk.StringVar()
primary_label = ttk.Label(root, textvariable=primary_var)
primary_label.grid(row=2, column=1, padx=10, pady=5, sticky=tk.W)

# Create label to display "Secondary"
secondary_label_text = tk.StringVar(value="Secondary")
secondary_label = ttk.Label(root, textvariable=secondary_label_text)
secondary_label.grid(row=3, column=0, padx=10, pady=5, sticky=tk.W)

secondary_var = tk.StringVar()
secondary_label = ttk.Label(root, textvariable=secondary_var)
secondary_label.grid(row=3, column=1, padx=10, pady=5, sticky=tk.W)

# Create label to display "Third"
third_label_text = tk.StringVar(value="Third")
third_label = ttk.Label(root, textvariable=third_label_text)
third_label.grid(row=4, column=0, padx=10, pady=5, sticky=tk.W)

third_var = tk.StringVar()
third_label = ttk.Label(root, textvariable=third_var)
third_label.grid(row=4, column=1, padx=10, pady=5, sticky=tk.W)

# Call search function to display initial item
search_items()

# Start GUI
root.mainloop()

# %%
import tkinter as tk
from tkinter import ttk
from tkinter import *
import csv

# Define function to search for items in CSV file


def search_items(event=None):
    search_term = search_var.get()
    search_results = []
    for item in items:
        if search_term.lower() in item[0].lower():
            search_results.append(item[0])
    search_box.config(values=search_results)

# Define function to select item from dropdown


def select_item(event=None):
    selected_item = search_var.get()
    for item in items:
        if selected_item == item[0]:
            selection_var.set(item[0])
            primary_var.set(item[1])
            secondary_var.set(item[2])
            third_var.set(item[3])
            break
    else:
        selection_var.set("No matches found")
        primary_var.set("")
        secondary_var.set("")
        third_var.set("")


# Load items from CSV file
with open('src/csv/TheMatrix.csv', newline='') as csvfile:
    items_reader = csv.reader(csvfile)
    items = list(items_reader)
# Create GUI
root = tk.Tk()
root.title("Search Bar Example")
root.geometry("400x300")
canvas = tk.Canvas(root, width=200, height=50)
canvas.grid(row=0, column=1, sticky='ne')
# sets the image paths to easily change them later
smc_logo = './src/images/smc-logo.png'
smc_seal = './src/images/smc-seal.png'


img = PhotoImage(file=smc_seal)
img = img.subsample(4)  # resize the image to 1/4 of its original size
canvas.create_image(0, 0, anchor='nw', image=img)
canvas.grid(row=0, column=0, sticky='nw')

# Add the header text to the canvas
header_text = "SMC Ticket Matrix"
canvas.create_text(110, 25, text=header_text, fill='green')
# Create search box
search_var = tk.StringVar()
search_box = ttk.Combobox(root, textvariable=search_var)
search_box.grid(row=0, column=1, padx=10, pady=10)
# Bind selection function to selection event
search_box.bind('<<ComboboxSelected>>', select_item)
# Bind search function to key release event
search_box.bind('<KeyRelease>', search_items)

# Create label to display "Selection"
selection_label_text = tk.StringVar(value="Selection")
selection_label = ttk.Label(root, textvariable=selection_label_text)
selection_label.grid(row=1, column=0, padx=10, pady=5, sticky=tk.W)

# Create label to display current selection
selection_var = tk.StringVar()
selection_label = ttk.Label(root, textvariable=selection_var)
selection_label.grid(row=1, column=1, padx=10, pady=5, sticky=tk.W)

# Create label to display "Primary"
primary_label_text = tk.StringVar(value="Primary")
primary_label = ttk.Label(root, textvariable=primary_label_text)
primary_label.grid(row=2, column=0, padx=10, pady=5, sticky=tk.W)

# Create labels to display information about selected item
primary_var = tk.StringVar()
primary_label = ttk.Label(root, textvariable=primary_var)
primary_label.grid(row=2, column=1, padx=10, pady=5, sticky=tk.W)

# Create label to display "Secondary"
secondary_label_text = tk.StringVar(value="Secondary")
secondary_label = ttk.Label(root, textvariable=secondary_label_text)
secondary_label.grid(row=3, column=0, padx=10, pady=5, sticky=tk.W)

secondary_var = tk.StringVar()
secondary_label = ttk.Label(root, textvariable=secondary_var)
secondary_label.grid(row=3, column=1, padx=10, pady=5, sticky=tk.W)

# Create label to display "Third"
third_label_text = tk.StringVar(value="Third")
third_label = ttk.Label(root, textvariable=third_label_text)
third_label.grid(row=4, column=0, padx=10, pady=5, sticky=tk.W)

third_var = tk.StringVar()
third_label = ttk.Label(root, textvariable=third_var)
third_label.grid(row=4, column=1, padx=10, pady=5, sticky=tk.W)

# Call select function to display initial item
select_item()

root.mainloop()
